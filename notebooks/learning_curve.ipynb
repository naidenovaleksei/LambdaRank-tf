# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("./history/model14.csv", index_col=0)

# %%
df.plot()
plt.grid()

# %%
df = pd.read_csv("./history/model15.csv", index_col=0)

# %%
df.plot()
plt.grid()

# %%
df = pd.read_csv("./history/model16.csv", index_col=0)

# %%
df.plot()
plt.grid()

# %%
df = pd.read_csv("./history/model17.csv", index_col=0)

# %%
df.plot()
plt.grid()
